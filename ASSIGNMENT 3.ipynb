# %% [markdown]
# **Student_Name:Ruturaj Bhandalkar.**
#
# **Roll No:24AI022**
#
# **Subject:DBMS**
#
# **Div:A Batch:A**
#
# **ASSIGNMENT**
#
# -   **Create the schema of the table**
#
# > create database studentdb;
# >
# > use studentdb;
# >
# > create table student(
# >
# > student_id int,
# >
# > name varchar(20),
# >
# > dept varchar(20),
# >
# > marks int,
# >
# > city varchar(10)
# >
# > );
#
# OUTPUT:
#
# <img src="attachment:media/image1.png" style="width:4.5838in;height:0.75833in" />
#
# **a)ALTER TABLE**
#
# -   **Add a new column**
#
# > alter table student
# >
# > add age int;
#
# <img src="attachment:media/image2.png" style="width:4.68056in;height:0.8in" />
#
# -   **modify column datatype**
#
# alter table student
#
# modify age varchar(3);
#
# <img src="attachment:media/image3.png" style="width:4.08958in;height:1.3in" />
#
# -   **Drop a column**
#
# **OUTPUT:**
#
# > <img src="attachment:media/image1.png" style="width:4.5838in;height:0.75833in" />
#
# **b)DROP TABLE**
#
# drop table student;
#
# *output: All data and structure will be lost.*
#
# **c)INDEX operation**
#
# -   **create an index**
#
# > create index idx_student_name
# >
# > on student(name);
#
# OUTPUT:
#
# > <img src="attachment:media/image4.png" style="width:4.48333in;height:1.16667in" />
#
# -   **drop an index**
#
# > alter table student
# >
# > drop index idx_student_name;
# >
# > *output:index idx_student_name is deleted.*
#
# -   **Insert a data**
#
# > insert into student
# >
# > (student_id,name,dept,marks,city)
# >
# > values
# >
# > (101,'ruturaj','aiml',78,'satara'),
# >
# > (102,'sahil','aiml',90,'pune'),
# >
# > (103,'raj','aiml',82,'satara'),
# >
# > (104,'mahil','aiml',74,'pune'),
# >
# > (105,'rakesh','aiml',70,'satara'),
# >
# > (106,'priya','aiml',86,'pune');
#
# OUTPUT:
#
# > <img src="attachment:media/image5.png" style="width:4.95833in;height:1.51597in" />
#
# **d)relational operators**
#
# > select \* from student
# >
# > where marks \> 70
#
# <img src="attachment:media/image6.png" style="width:5.03333in;height:1.48318in" />OUTPUT:
#
# **e)Pattern Matching (Like)**
#
# -   **Name starting with ‘r’**
#
# > SELECT \* FROM student
# >
# > where name like 'r%';
#
# OUTPUT:
#
# > <img src="attachment:media/image7.png" style="width:4.84167in;height:1.06597in" />
#
# -   **Name ending with ‘j’**
#
# SELECT \* FROM student
#
# where name like '%j';
#
# <img src="attachment:media/image8.png" style="width:4.775in;height:0.81667in" />**OUTPUT:**
#
# **f) Aggregate Functions with GROUP BY & HAVING**
#
# **COMMON AGGREGATE FUNCTIONS:**
#
# -   **COUNT()**
#
# -   **SUM()**
#
# -   **AVG()**
#
# -   **MAX()**
#
# -   **MIN()**
#
# **Average marks department-wise**
#
# Select dept, avg(marks) as avg_marks
#
# From student
#
# Group by dept;
#
# OUTPUT:
#
# <img src="attachment:media/image9.png" style="width:3.9in;height:0.85833in" />
#
# -   **Department with average marks \> 70**
#
# Select dept, avg(marks) as avg_marks
#
# From student
#
# Group by dept
#
# having avg(marks) \>70;
#
# OUTPUT:
#
# <img src="attachment:media/image9.png" style="width:3.9in;height:0.85833in" />
#
# **g) Nested Queries (Subqueries)**
#
# -   **student scoring more than the average marks.**
#
# > Select \* from student
# >
# > Where marks \> (select avg(marks)
# >
# > From student
# >
# > );
#
# **OUTPUT:**
#
# > <img src="attachment:media/image10.png" style="width:4.51667in;height:1.20833in" />
#
# **h) Set Operators**
#
# -   **Union Example**
#
# > SELECT name
# >
# > FROM student
# >
# > WHERE city = 'pune'
# >
# > UNION
# >
# > SELECT name
# >
# > FROM student
# >
# > WHERE city = 'satara';
#
# OUTPUT:
#
# <img src="attachment:media/image11.png" style="width:2.04167in;height:1.43264in" />
#
# **i)VIEWS**
#
# -   **create a view**
#
# > create view HighScorers as
# >
# > select name, marks
# >
# > from student
# >
# > where marks \> 80;
#
# -   **use a view**
#
# > select \* from HighScorers;
#
# OUTPUT:
#
# <img src="attachment:media/image12.png" style="width:3.475in;height:1.21667in" />
#
# **j) SORTING (ORDER BY)**
#
# -   **sort by marks (ascending)**
#
# > select \* from student
# >
# > order by marks;
#
# OUTPUT:
#
# <img src="attachment:media/image13.png" style="width:4.375in;height:1.56667in" />
#
# -   **Sort by marks (descending)**
#
# > select \* from student
# >
# > order by marks DESC;
#
# OUTPUT:
#
# <img src="attachment:media/image14.png" style="width:4.39205in;height:1.47513in" />
